# %% [markdown]
# # Small Business Sales Insights & Predictive Forecasting
#
# This Jupyter Notebook serves as the interactive interface for the **Sales Insights & Forecasting Project**.
#
# ### Project Workflow:
# 1. **Data Preprocessing & Cleaning**: Detects and eliminates duplicates, imputes missing values, parses mixed dates, and rectifies outliers (negative quantities, pricing typos).
# 2. **Exploratory Data Analysis (EDA)**: Computes business KPIs and generates detailed revenue summaries by product, category, region, and segment.
# 3. **Visualizations**: Generates and saves five high-quality business charts (Monthly Sales Trend, Category Share, Regional Sales, Segment Box Plots, Forecast Comparison).
# 4. **Weekly Sales Forecasting Model**: Trains a time-series regression model using Scikit-Learn lag features and evaluates its forecasting accuracy.
#
# ---

# %% [markdown]
# ## Run the Complete Pipeline
# Execute the cell below to load the raw data, perform data cleaning, output all statistics, save the figures, and train the forecasting model.

# %%
# %run scripts/sales_analysis.py

# %% [markdown]
# ## View Generated Visualizations
# Once execution is complete, the following code cells allow you to display the saved figures directly in the notebook.

# %%
from IPython.display import Image, display
import os

vis_dir = 'visualizations'
charts = ['monthly_sales_trend.png', 'category_revenue.png', 'regional_performance.png', 'customer_segments.png', 'actual_vs_predicted.png']

for chart in charts:
    chart_path = os.path.join(vis_dir, chart)
    if os.path.exists(chart_path):
        print(f"\n--- Displaying {chart} ---")
        display(Image(filename=chart_path))
    else:
        print(f"Chart not found: {chart_path}")
